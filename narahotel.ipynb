# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# CSV CANAIS DE VENDA
#
# (p)coluna canal de venda tem 'ota' o que seria?
# (t)coluna comissão pct esta em str
#
#
# CSV CLIENTE
#
# (t) clientes duplicados (3?)
# (p) temos clientes com todas as informações idênticas salvo coluna de estado de origem
#
# (t) coluna de tipo de cliente precisa ser padroni.
# (p) NaN existente, não deveria constar como nulo?
# (t) coluna estado de origem tem que ser padroni.
# (p) coluna faixa_etaria com muito NaN PERGUNTA DE NEGOCIO, É IMPORTANTE PARA A LEITURA DO NEGOCIO
#
#
# CSV FUNCIONARIO
#
# (t) Coluna salatio str
# (p) coluna salario 6 NaN IMPORTANTE PARA A LEITURA?
# (t) leta maiuscula na coluna cargo
#
#
# CSV RESERVAS
#
# (t) Coluna status reserva precisa ser padronizado
# (t) NaN na coluna id_canal e avaliação_ cliente IMPORTANTE PARA LEITURA
# (t) Coluna forma de pagamento precisa padronizar
#
# CSV tipos quarto
#
# (t) coluna valor diaria base como str
#
#
# CSV UNIDADES
#
# (t) regiao precisa padronizar espaço no serra
# (t) categoria hotel padronizar, nome ext. str
# (t) padronizar nome das regiões, csv conta com: Capital, Serra, capital, CAP,Baixada Fluminense, Baixada fluminense,Serra
# (t) numero de quartos esta float precisa ir para int
# (p) número de quarto em Paraty e Petrópolis

# %%
pd.read_csv ('canais_venda.csv', sep=';')
pd.read_csv ('clientes.csv', sep=';')
pd.read_csv ('funcionarios.csv', sep=';')
pd.read_csv ('reservas.csv', sep=';')
pd.read_csv ('tipos_quarto.csv', sep=';')
pd.read_csv ('unidades.csv', sep=';')
# Out:
#     id_unidade                   nome_unidade          cidade  \
# 0            1             NaraHoteis Ipanema  Rio de Janeiro
# 1            2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 3            4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 6            7          NaraHoteis Petrópolis      Petrópolis
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 9           10              NaraHoteis Paraty          Paraty
# 10          11      NaraHoteis Angra dos Reis  Angra dos Reis
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
# 12          13  NaraHoteis Copacabana Premium  Rio de Janeiro
#
#                 regiao  categoria_hotel(estrelas)  num_quartos_total
# ...

# %%
df = pd.read_csv('unidades.csv', sep=';')

print(df.shape)
display(df.head())
display(df.tail())
display(df.dtypes)
# Out:
# (13, 6)
#    id_unidade                   nome_unidade          cidade  \
# 0           1             NaraHoteis Ipanema  Rio de Janeiro
# 1           2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2           3              NaraHoteis Centro  Rio de Janeiro
# 3           4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4           5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
#
#                regiao  categoria_hotel(estrelas)  num_quartos_total
# 0             Capital                          5                 80
# 1             Capital                          4                120
# 2             Capital                          3                 60
# 3             Capital                          4                 45
# 4  Baixada Fluminense                          3                 50
#     id_unidade                   nome_unidade          cidade       regiao  \
# 8            9            NaraHoteis Friburgo   Nova Friburgo        Serra
# ...

# %%
df[df.duplicated(subset=['num_quartos_total'], keep=False)]
# Out:
#     id_unidade                   nome_unidade          cidade  \
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
#
#                 regiao  categoria_hotel(estrelas)  num_quartos_total
# 2              Capital                          3                 60
# 4   Baixada Fluminense                          3                 50
# 5   Baixada Fluminense                          3                 55
# 7                Serra                          4                 60
# 8                Serra                          4                 55
# 11         Costa Verde                          4                 50

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id_unidade, nome_unidade, cidade, regiao, categoria_hotel(estrelas), num_quartos_total]
# Index: []

# %%
df['categoria_hotel'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
mapa = {
    '4 estrelas':                '4',
    '4 Estrelas':                '4',
    '3*':                        '3',
    'Três Estrelas':             '3',
    '3 estrelas':               '3',
    '5 estrelas':                '5',
    'cinco estrelas':            '5'
}
df['categoria_hotel'] = df['categoria_hotel'].map(mapa).fillna(df['categoria_hotel'])

print('Após mapeamento:')
print(sorted(df['categoria_hotel'].unique()))
# Out:
# Após mapeamento:
# ['3', '4', '5']

# %%
df['categoria_hotel'].value_counts()
# Out:
# categoria_hotel
# 4    5
# 5    4
# 3    3
# Name: count, dtype: int64

# %%
df
# Out:
#     id_unidade                   nome_unidade          cidade  \
# 0            1             NaraHoteis Ipanema  Rio de Janeiro
# 1            2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 3            4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 6            7          NaraHoteis Petrópolis      Petrópolis
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 9           10              NaraHoteis Paraty          Paraty
# 10          11      NaraHoteis Angra dos Reis  Angra dos Reis
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
#
#                 regiao categoria_hotel  num_quartos_total
# 0              Capital               5               80.0
# ...

# %%
df['regiao'].value_counts()
# Out:
# regiao
# Costa Verde           3
# Capital               2
# Serra                 2
# capital               1
# CAP                   1
# Baixada Fluminense    1
# Baixada fluminense    1
# Serra                 1
# Name: count, dtype: int64

# %%
reg = {
    'capital':                'Capital',
    'CAP':                  'Capital',
    'Serra':                   'Serra',
     'Baixada fluminense':             'Baixada Fluminense'
}
df['regiao'] = df['regiao'].map(reg).fillna(df['regiao'])

print('Após mapeamento:')
print(sorted(df['regiao'].unique()))
# Out:
# Após mapeamento:
# ['Baixada Fluminense', 'Capital', 'Costa Verde', 'Serra', 'Serra ']

# %%
df['regiao'] = df['regiao'].str.strip().str.title()
df
# Out:
#     id_unidade                   nome_unidade          cidade  \
# 0            1             NaraHoteis Ipanema  Rio de Janeiro
# 1            2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 3            4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 6            7          NaraHoteis Petrópolis      Petrópolis
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 9           10              NaraHoteis Paraty          Paraty
# 10          11      NaraHoteis Angra dos Reis  Angra dos Reis
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
#
#                 regiao categoria_hotel  num_quartos_total
# 0              Capital               5               80.0
# ...

# %%
df['num_quartos_total'] = df['num_quartos_total'].astype("Int64")
df
# Out:
#     id_unidade                   nome_unidade          cidade  \
# 0            1             NaraHoteis Ipanema  Rio de Janeiro
# 1            2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 3            4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 6            7          NaraHoteis Petrópolis      Petrópolis
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 9           10              NaraHoteis Paraty          Paraty
# 10          11      NaraHoteis Angra dos Reis  Angra dos Reis
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
#
#                 regiao categoria_hotel  num_quartos_total
# 0              Capital               5                 80
# ...

# %%
df = df.rename(columns={'categoria_hotel': 'categoria_hotel(estrelas)'})
df
# Out:
#     id_unidade                   nome_unidade          cidade  \
# 0            1             NaraHoteis Ipanema  Rio de Janeiro
# 1            2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 3            4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 6            7          NaraHoteis Petrópolis      Petrópolis
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 9           10              NaraHoteis Paraty          Paraty
# 10          11      NaraHoteis Angra dos Reis  Angra dos Reis
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
#
#                 regiao categoria_hotel(estrelas)  num_quartos_total
# 0              Capital                         5                 80
# ...

# %%
df['categoria_hotel(estrelas)'] = pd.to_numeric(df['categoria_hotel(estrelas)'], errors="coerce").astype("Int64")
df
# Out:
#     id_unidade                   nome_unidade          cidade  \
# 0            1             NaraHoteis Ipanema  Rio de Janeiro
# 1            2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 3            4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 6            7          NaraHoteis Petrópolis      Petrópolis
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 9           10              NaraHoteis Paraty          Paraty
# 10          11      NaraHoteis Angra dos Reis  Angra dos Reis
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
#
#                 regiao  categoria_hotel(estrelas)  num_quartos_total
# 0              Capital                          5                 80
# ...

# %%
df.to_csv('unidades.csv', sep=';', index=False)
df
# Out:
#     id_unidade                   nome_unidade          cidade  \
# 0            1             NaraHoteis Ipanema  Rio de Janeiro
# 1            2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 3            4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 6            7          NaraHoteis Petrópolis      Petrópolis
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 9           10              NaraHoteis Paraty          Paraty
# 10          11      NaraHoteis Angra dos Reis  Angra dos Reis
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
#
#                 regiao  categoria_hotel(estrelas)  num_quartos_total
# 0              Capital                          5                 80
# ...

# %% [markdown]
# CSV UNIDADES
#
# (t) padronizado categoria hotel, deixados apenas números,
# (t) padronizado nome das regiões: Capital, Serra, Baixada Fluminense, Costa Verde
# (t) numero de quartos esta float precisa ir para int
# (p) número de quarto em Paraty e Petrópolis

# %%
df_tipo = pd.read_csv('tipos_quarto.csv', sep=';')

print(df_tipo.shape)
display(df_tipo.head())
display(df_tipo.tail())
display(df_tipo.dtypes)
# Out:
# (8, 4)
#    id_tipo_quarto     descricao  capacidade_max  valor_diaria_base
# 0               1      Standard               2              280.0
# 1               2      Superior               2              420.0
# 2               3        Deluxe               3              580.0
# 3               4         Suite               4              950.0
# 4               5  Suíte Master               4             1500.0
#    id_tipo_quarto                descricao  capacidade_max  valor_diaria_base
# 3               4                    Suite               4              950.0
# 4               5             Suíte Master               4             1500.0
# 5               6          Suíte Vista Mar               2              620.0
# 6               7  Suíte Master Copacabana               3              780.0
# 7               8   Cobertura Presidencial               4              950.0
# id_tipo_quarto         int64
# descricao                str
# capacidade_max         int64
# ...

# %%
df_tipo['descricao'] = df_tipo['descricao'].str.strip().str.title()
df_tipo
# Out:
#    id_tipo_quarto                descricao  capacidade_max  valor_diaria_base
# 0               1                 Standard               2              280.0
# 1               2                 Superior               2              420.0
# 2               3                   Deluxe               3              580.0
# 3               4                    Suite               4              950.0
# 4               5             Suíte Master               4             1500.0
# 5               6          Suíte Vista Mar               2              620.0
# 6               7  Suíte Master Copacabana               3              780.0
# 7               8   Cobertura Presidencial               4              950.0

# %%
df_tipo['valor_diaria_base'] = (
df_tipo['valor_diaria_base']
.str.replace('R$', '', regex=False)
.str.replace(' ', '', regex=False)
.str.replace('.', '', regex=False) # remove separador de milhar
.str.replace(',', '.', regex=False)
.astype(float)
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[283], line 3
#       1 df_tipo['valor_diaria_base'] = (
#       2 df_tipo['valor_diaria_base']
# ----> 3 .str.replace('R$', '', regex=False)
#       4 .str.replace(' ', '', regex=False)
#       5 .str.replace('.', '', regex=False) # remove separador de milhar
#       6 .str.replace(',', '.', regex=False)
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# ...

# %%
df_tipo.to_csv('tipos_quarto.csv', sep=';', index=False)

# %%
df_tipo
# Out:
#    id_tipo_quarto     descricao  capacidade_max  valor_diaria_base
# 0               1      Standard               2              280.0
# 1               2      Superior               2              420.0
# 2               3        Deluxe               3              580.0
# 3               4         Suite               4              950.0
# 4               5  Suíte Master               4             1500.0
# 5               3        Deluxe               3              580.0

# %% [markdown]
# padronizado a escrita da couna 'descrição'
# coluna 'valor_diaria_base'

# %%
df_res = pd.read_csv('reservas.csv', sep=';')
df_re

print(df_res.shape)
display(df_res.head())
display(df_res.tail())
display(df_res.dtypes)

# %%
df_res['data_checkin'] = pd.to_datetime(
    df_res['data_checkin'],
    format='mixed',
    dayfirst=True,
    errors='coerce'
)

# %%
df_res['data_checkout'] = pd.to_datetime(
    df_res['data_checkout'],
    format='mixed',
    dayfirst=True,
    errors='coerce'
)

# %%
print (df_res['status_reserva'].sort_values().unique())


print(df_res['forma_pagamento'].sort_values().unique())
# Out:
# <StringArray>
# [   'Cancel.',  'Cancelada',  'Concluida',  'Concluída',      'Conf.',
#  'Confirmada',    'No-Show']
# Length: 7, dtype: str
# <StringArray>
# [       'C. Crédito',    'Cartao Credito',     'Cartao Debito',
#  'Cartão De Crédito',  'Cartão De Débito',              'Cash',
#                 'Cc',                'Cd',              'Cred',
#           'Dinheiro',               'Déb',               'Pix',
#                'Ted',     'Transferencia',     'Transferência']
# Length: 15, dtype: str

# %%
rese = {
    'Cancel.':                'Capital',
    'CAP':                  'Capital',
    'Serra':                   'Serra',
     'Baixada fluminense':             'Baixada Fluminense'
}
df['reseiao'] = df['reseiao'].map(rese).fillna(df['regiao'])

print('Após mapeamento:')
print(sorted(df['regiao'].unique()))

# %%
df_res['status_reserva'] = df_res['status_reserva'].str.strip().str.title()
df_res['forma_pagamento'] = df_res['forma_pagamento'].str.strip().str.title()
df_res

# %%
df_res.to_csv('reservas.csv', sep=';', index=False)
df_res
# Out:
#       id_reserva  id_unidade  id_tipo_quarto  id_cliente  id_canal  \
# 0              1           5               1           3       2.0
# 1              2           5               1         261       4.0
# 2              3          10               4          49       4.0
# 3              4           6               2          23       2.0
# 4              5           7               1          42       1.0
# ...          ...         ...             ...         ...       ...
# 2452        2453          10               3         210       4.0
# 2453        2454           7               3         271       2.0
# 2454        2455           7               1         143       1.0
# 2455        2456           8               4         176       1.0
# 2456        2457           6               3         160       1.0
#
#      data_checkin data_checkout  qtd_diarias  num_hospedes  avaliacao_hospede  \
# 0      2024-04-28    2024-04-30            2             1                4.0
# ...

# %% [markdown]
# alterado para datetime data checkin e checkout
# nome com letra maisúcula status reserva e forma de pagamento

# %%
df_fun = pd.read_csv('funcionarios.csv', sep=';')
df_fun

print(df_fun.shape)
display(df_fun.head())
display(df_fun.tail())
display(df_fun.dtypes)
# Out:
# (134, 7)
#    id_funcionario  id_unidade            nome                cargo  \
# 0               1           1   Gabriela Lima  Auxiliar De Limpeza
# 1               2           1    Abel Correia            Segurança
# 2               3           1   Sara Teixeira  Analista Financeiro
# 3               4           1  Julia Monteiro  Auxiliar De Limpeza
# 4               5           1   Daniela Ramos  Auxiliar De Limpeza
#
#   departamento  salario data_admissao
# 0   Governança   2139.0    2020-05-10
# 1    Segurança   1746.0    2021-12-29
# 2   Financeiro   5356.0    2022-01-03
# 3   Governança   2070.0    2019-10-06
# 4   Governança   1572.0    2018-10-16
#      id_funcionario  id_unidade           nome          cargo   departamento  \
# 129             130          12  Fernanda Cruz     Manutenção     Manutenção
# 130             131          12   Abel Correia        Gerente  Administração
# 131             132          12    Yuri Castro  Recepcionista       Recepção
# ...

# %%
df_fun['cargo'] = df_fun['cargo'].str.strip().str.title()

# %%
df_fun['cargo'].value_counts()
# Out:
# cargo
# Manutenção             24
# Camareira              21
# Segurança              20
# Auxiliar De Limpeza    17
# Recepcionista          15
# Cozinheiro             15
# Analista Financeiro    13
# Gerente                 9
# Name: count, dtype: int64

# %%
df_fun['departamento'].value_counts()
# Out:
# departamento
# Governança             38
# Manutenção             24
# Segurança              20
# Recepção               15
# Alimentos e Bebidas    15
# Financeiro             13
# Administração           9
# Name: count, dtype: int64

# %%
dep = {
    'Gov.':                'Governança',
    'Admin.':                  'Administração',
    'A&B':                   'Alimentos e Bebidas',
     'Baixada fluminense':             'Baixada Fluminense'
}
df_fun['departamento'] = df_fun['departamento'].map(dep).fillna(df_fun['departamento'])

print('Após mapeamento:')
print(sorted(df_fun['departamento'].unique()))
# Out:
# Após mapeamento:
# ['Administração', 'Alimentos e Bebidas', 'Financeiro', 'Governança', 'Manutenção', 'Recepção', 'Segurança']

# %%
df_fun['salario'] = (
df_fun['salario']
.str.replace('.', '', regex=False)
.str.replace('"', '', regex=False)
.str.replace(',', '.', regex=False)
.astype(float)
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[300], line 3
#       1 df_fun['salario'] = (
#       2 df_fun['salario']
# ----> 3 .str.replace('.', '', regex=False)
#       4 .str.replace('"', '', regex=False)
#       5 .str.replace(',', '.', regex=False)
#       6 .astype(float)
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
# ...

# %%
df_fun['data_admissao'] = pd.to_datetime(
    df_fun['data_admissao'],
    format='mixed',
    dayfirst=True,
    errors='coerce'
)

# %%
df_fun.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_funcionario  134 non-null    int64
#  1   id_unidade      134 non-null    int64
#  2   nome            134 non-null    str
#  3   cargo           134 non-null    str
#  4   departamento    134 non-null    str
#  5   salario         128 non-null    float64
#  6   data_admissao   134 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(1), int64(2), str(3)
# memory usage: 7.5 KB

# %%
display(df_fun.dtypes)
df_fun.to_csv('funcionarios.csv', sep=';', index=False)
df_fun
# Out:
# id_funcionario             int64
# id_unidade                 int64
# nome                         str
# cargo                        str
# departamento                 str
# salario                  float64
# data_admissao     datetime64[us]
# dtype: object
#      id_funcionario  id_unidade            nome                cargo  \
# 0                 1           1   Gabriela Lima  Auxiliar De Limpeza
# 1                 2           1    Abel Correia            Segurança
# 2                 3           1   Sara Teixeira  Analista Financeiro
# 3                 4           1  Julia Monteiro  Auxiliar De Limpeza
# 4                 5           1   Daniela Ramos  Auxiliar De Limpeza
# ..              ...         ...             ...                  ...
# 129             130          12   Fernanda Cruz           Manutenção
# 130             131          12    Abel Correia              Gerente
# 131             132          12     Yuri Castro        Recepcionista
# ...

# %% [markdown]
# padronizado escrita cargo, com letras maisuculas
# padronizado departamento tirado abreviações
# sálario padronizado para float e retirado datas
# data admissao para datetime

# %%
df_cli = pd.read_csv ('clientes.csv', sep=';')
df_cli
print(df_cli.shape)
display(df_cli.head())
display(df_cli.tail())
display(df_cli.dtypes)
# Out:
# (301, 6)
#    id_cliente            nome   cidade_origem estado_origem faixa_etaria  \
# 0           1     Otavio Reis       São Paulo            SP        18-25
# 1           2   Larissa Sousa        Curitiba            PR        18-25
# 2           3  Tatiana Coelho  Rio de Janeiro            RJ          65+
# 3           4   Wilson Duarte        Brasília            DF        26-35
# 4           5   Gabriela Lima  Rio de Janeiro            RJ        46-55
#
#     tipo_cliente
# 0    Corporativo
# 1  Pessoa Física
# 2    Corporativo
# 3    Corporativo
# 4  Pessoa Física
#      id_cliente                nome cidade_origem estado_origem faixa_etaria  \
# 296         297       Roberta Leite      Curitiba            PR        56-65
# 297         298       Eduardo Lopes     São Paulo            SP        36-45
# 298         299  Vanessa Cavalcanti      Curitiba            PR        46-55
# 299         300     Julia Monteiro       Brasília            DF        36-45
# ...

# %%
df_cli[df_cli.isnull().any(axis=1)]

# %%
df_cli['cidade_origem'].sort_values().unique()
# Out:
# <StringArray>
# ['Belo Horizonte',       'Brasília',       'Curitiba',      'Fortaleza',
#         'Niterói',         'Recife', 'Rio de Janeiro',       'Salvador',
#       'São Paulo']
# Length: 9, dtype: str

# %%
df_cli['estado_origem'].sort_values()

# %%
print(sorted(df_cli['cidade_origem'].unique()))
print(sorted(df_cli['estado_origem'].unique()))
# Out:
# ['Belo Horizonte', 'Brasília', 'Curitiba', 'Fortaleza', 'Niterói', 'Recife', 'Rio de Janeiro', 'Salvador', 'São Paulo']
# ['BA', 'CE', 'DF', 'MG', 'PE', 'PR', 'RJ', 'SP']

# %%
mapa_cidades = {
    'r.j.': 'RJ',
    'rj': 'RJ',
    'Rio de Janeiro': 'RJ'
}

df_cli['estado_origem'] = df_cli['estado_origem'].map(mapa_cidades).fillna(df_cli['estado_origem'])

print('Após mapeamento:')
print(sorted(df_cli['estado_origem'].unique()))
# Out:
# Após mapeamento:
# ['AM', 'BA', 'CE', 'DF', 'ES', 'GO', 'MG', 'PA', 'PE', 'PR', 'RJ', 'RS', 'SC', 'SP']

# %%
mapa_cidade_estado = {
    "Belo Horizonte": "MG",
    "Brasília": "DF",
    "Curitiba": "PR",
    "Fortaleza": "CE",
    "Niterói": "RJ",
    "Recife": "PE",
    "Rio de Janeiro": "RJ",
    "Salvador": "BA",
    "São Paulo": "SP"
}


df_cli['estado_origem'] = df_cli['cidade_origem'].map(mapa_cidade_estado).fillna(df_cli['estado_origem'])


df_cli

# %%
df_cli['tipo_cliente'].sort_values().unique()
print(sorted(df_cli['tipo_cliente'].unique()))
# Out:
# ['Corporativo', 'Pessoa Física']

# %%
tipo = {
    'PF':   'Pessoa Física',
    'pessoa fisica':    'Pessoa Física',
    'pf':   'Pessoa Física',
    'PJ':   'Corporativo',
    'corporativo':  'Corporativo'
}

df_cli['tipo_cliente'] = df_cli['tipo_cliente'].map(tipo).fillna(df_cli['tipo_cliente'])

print('Após mapeamento:')
print(sorted(df_cli['tipo_cliente'].unique()))
# Out:
# Após mapeamento:
# ['Corporativo', 'Pessoa Física']

# %%
df_cli.loc[df_cli['id_cliente'] == 401, 'id_cliente'] = 401
df_cli.loc[(df_cli['id_cliente'] == 401)]
# Out:
#      id_cliente         nome cidade_origem estado_origem faixa_etaria  \
# 300         401  Carlos Neto       Niterói            RJ        36-45
#
#     tipo_cliente
# 300  Corporativo

# %%
df_cli.loc[300, 'id_cliente'] = 401
df_cli.iloc[46, :]
# Out:
# id_cliente                  47
# nome             Wesley Araujo
# cidade_origem           Recife
# estado_origem               PE
# faixa_etaria               65+
# tipo_cliente     Pessoa Física
# Name: 46, dtype: object

# %%
df_cli
df_cli.to_csv('clientes.csv', sep=';', index=False)

# %% [markdown]
# espelhado dados de estado de acordo com a cidade
# padronizado escrita do tipo cliente
# alterado id de cliente do Carlos Neto de 47 o que conflitava com o mesmo id de Wesley, para 401

# %%
df_can = pd.read_csv('canais_venda.csv', sep=';')

print(df_tipo.shape)
display(df_tipo.head())
display(df_tipo.tail())
display(df_tipo.dtypes)
# Out:
# (6, 4)
#    id_tipo_quarto     descricao  capacidade_max  valor_diaria_base
# 0               1      Standard               2              280.0
# 1               2      Superior               2              420.0
# 2               3        Deluxe               3              580.0
# 3               4         Suite               4              950.0
# 4               5  Suíte Master               4             1500.0
#    id_tipo_quarto     descricao  capacidade_max  valor_diaria_base
# 1               2      Superior               2              420.0
# 2               3        Deluxe               3              580.0
# 3               4         Suite               4              950.0
# 4               5  Suíte Master               4             1500.0
# 5               3        Deluxe               3              580.0
# id_tipo_quarto         int64
# descricao                str
# capacidade_max         int64
# valor_diaria_base    float64
# dtype: object

# %% [markdown]
# trabalhar no novos csvs

# %%
df_uni = pd.read_csv('unidades_novos.csv', sep=';')

print(df.shape)
display(df.head())
display(df.tail())
display(df.dtypes)

df.info()
# Out:
# (13, 6)
#    id_unidade                   nome_unidade          cidade  \
# 0           1             NaraHoteis Ipanema  Rio de Janeiro
# 1           2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2           3              NaraHoteis Centro  Rio de Janeiro
# 3           4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4           5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
#
#                regiao  categoria_hotel(estrelas)  num_quartos_total
# 0             Capital                          5                 80
# 1             Capital                          4                120
# 2             Capital                          3                 60
# 3             Capital                          4                 45
# 4  Baixada Fluminense                          3                 50
#     id_unidade                   nome_unidade          cidade       regiao  \
# 8            9            NaraHoteis Friburgo   Nova Friburgo        Serra
# ...

# %%
df = pd.concat([df, df_uni], ignore_index=True)
print (df.shape) 
display (df.head(13))
print(df.shape)
display(df.head())
display(df.tail())
display(df.dtypes)
# Out:
# (14, 6)
#     id_unidade                   nome_unidade          cidade  \
# 0            1             NaraHoteis Ipanema  Rio de Janeiro
# 1            2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 3            4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 6            7          NaraHoteis Petrópolis      Petrópolis
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 9           10              NaraHoteis Paraty          Paraty
# 10          11      NaraHoteis Angra dos Reis  Angra dos Reis
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
# 12          13  NaraHoteis Copacabana Premium  Rio de Janeiro
#
#                 regiao  categoria_hotel(estrelas)  num_quartos_total
# ...

# %%
df ['num_quartos_total'] = df ['num_quartos_total'].astype('Int64')
df
# Out:
#     id_unidade                   nome_unidade          cidade  \
# 0            1             NaraHoteis Ipanema  Rio de Janeiro
# 1            2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 3            4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 6            7          NaraHoteis Petrópolis      Petrópolis
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 9           10              NaraHoteis Paraty          Paraty
# 10          11      NaraHoteis Angra dos Reis  Angra dos Reis
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
# 12          13  NaraHoteis Copacabana Premium  Rio de Janeiro
# 13          13  NaraHoteis Copacabana Premium  Rio de Janeiro
#
# ...

# %%
df.info()
df.duplicated().sum()
df[df.duplicated(keep=False)]
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id_unidade                 14 non-null     int64
#  1   nome_unidade               14 non-null     str
#  2   cidade                     14 non-null     str
#  3   regiao                     14 non-null     str
#  4   categoria_hotel(estrelas)  14 non-null     int64
#  5   num_quartos_total          14 non-null     Int64
# dtypes: Int64(1), int64(2), str(3)
# memory usage: 818.0 bytes
#     id_unidade                   nome_unidade          cidade   regiao  \
# 12          13  NaraHoteis Copacabana Premium  Rio de Janeiro  Capital
# 13          13  NaraHoteis Copacabana Premium  Rio de Janeiro  Capital
#
#     categoria_hotel(estrelas)  num_quartos_total
# 12                          5                 40
# 13                          5                 40

# %%
df = df.drop_duplicates()
df
# Out:
#     id_unidade                   nome_unidade          cidade  \
# 0            1             NaraHoteis Ipanema  Rio de Janeiro
# 1            2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 3            4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 6            7          NaraHoteis Petrópolis      Petrópolis
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 9           10              NaraHoteis Paraty          Paraty
# 10          11      NaraHoteis Angra dos Reis  Angra dos Reis
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
# 12          13  NaraHoteis Copacabana Premium  Rio de Janeiro
#
#                 regiao  categoria_hotel(estrelas)  num_quartos_total
# ...

# %%
df.loc[6, "num_quartos_total"] = 70
df.loc[9, "num_quartos_total"] = 75

# %%
df.to_csv('unidades.concat.csv', sep=';', index=False)
df
# Out:
#     id_unidade                   nome_unidade          cidade  \
# 0            1             NaraHoteis Ipanema  Rio de Janeiro
# 1            2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 3            4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 6            7          NaraHoteis Petrópolis      Petrópolis
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 9           10              NaraHoteis Paraty          Paraty
# 10          11      NaraHoteis Angra dos Reis  Angra dos Reis
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
# 12          13  NaraHoteis Copacabana Premium  Rio de Janeiro
#
#                 regiao  categoria_hotel(estrelas)  num_quartos_total
# ...

# %% [markdown]
# concatenado csv unidades
# preenchido os números de quartos

# %%
df_tipon = pd.read_csv('tipos_quarto_novos.csv', sep=';')
print (df_tipon.shape)
print (df_tipon.dtypes)
df_tipon
# Out:
# (3, 4)
# id_tipo_quarto         int64
# descricao                str
# capacidade_max         int64
# valor_diaria_base    float64
# dtype: object
#    id_tipo_quarto                descricao  capacidade_max  valor_diaria_base
# 0               6          Suíte Vista Mar               2              620.0
# 1               7  Suíte Master Copacabana               3              780.0
# 2               8   Cobertura Presidencial               4              950.0

# %%
df_tipo_qt = pd.concat([df_tipo, df_tipon], ignore_index=True)

# %%
df_tipo_qt
# Out:
#     id_tipo_quarto                descricao  capacidade_max  valor_diaria_base
# 0                1                 Standard               2              280.0
# 1                2                 Superior               2              420.0
# 2                3                   Deluxe               3              580.0
# 3                4                    Suite               4              950.0
# 4                5             Suíte Master               4             1500.0
# 5                6          Suíte Vista Mar               2              620.0
# 6                7  Suíte Master Copacabana               3              780.0
# 7                8   Cobertura Presidencial               4              950.0
# 8                6          Suíte Vista Mar               2              620.0
# 9                7  Suíte Master Copacabana               3              780.0
# 10               8   Cobertura Presidencial               4              950.0

# %%
df_tipo_qt = df_tipo_qt.drop_duplicates()
df_tipo_qt
# Out:
#    id_tipo_quarto                descricao  capacidade_max  valor_diaria_base
# 0               1                 Standard               2              280.0
# 1               2                 Superior               2              420.0
# 2               3                   Deluxe               3              580.0
# 3               4                    Suite               4              950.0
# 4               5             Suíte Master               4             1500.0
# 5               6          Suíte Vista Mar               2              620.0
# 6               7  Suíte Master Copacabana               3              780.0
# 7               8   Cobertura Presidencial               4              950.0

# %%
df_tipo_qt.to_csv('tipos_quarto.concat.csv', sep=';', index=False)

# %% [markdown]
# concatenado tipo quarto

# %%
df_res = pd.read_csv ('reservas.csv', sep=';')
df_reser = pd.read_csv('reservas_novas.csv', sep=';')
df_reser.info()
df_res.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2207 entries, 0 to 2206
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_reserva         2207 non-null   int64
#  1   id_unidade         2207 non-null   int64
#  2   id_tipo_quarto     2207 non-null   int64
#  3   id_cliente         2207 non-null   int64
#  4   id_canal           2110 non-null   float64
#  5   data_checkin       2207 non-null   str
#  6   data_checkout      2207 non-null   str
#  7   qtd_diarias        2207 non-null   int64
#  8   num_hospedes       2207 non-null   int64
#  9   avaliacao_hospede  1898 non-null   float64
#  10  status_reserva     2207 non-null   str
#  11  forma_pagamento    2207 non-null   str
# dtypes: float64(2), int64(6), str(4)
# memory usage: 207.0 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 2457 entries, 0 to 2456
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ...

# %%
df_reserva = pd.concat([df_res, df_reser], ignore_index=True)
df_reserva
# Out:
#       id_reserva  id_unidade  id_tipo_quarto  id_cliente  id_canal  \
# 0              1           5               1           3       2.0
# 1              2           5               1         261       4.0
# 2              3          10               4          49       4.0
# 3              4           6               2          23       2.0
# 4              5           7               1          42       1.0
# ...          ...         ...             ...         ...       ...
# 4659        3198           7               5         268       1.0
# 4660        3490           9               3          48       1.0
# 4661        4579          13               6         306       4.0
# 4662        3882          11               1         100       4.0
# 4663        4183           3               1         102       1.0
#
#      data_checkin data_checkout  qtd_diarias  num_hospedes  avaliacao_hospede  \
# 0      2024-04-28    2024-04-30            2             1                4.0
# ...

# %%
df_reserva
# Out:
#       id_reserva  id_unidade  id_tipo_quarto  id_cliente  id_canal  \
# 0              1           5               1           3       2.0
# 1              2           5               1         261       4.0
# 2              3          10               4          49       4.0
# 3              4           6               2          23       2.0
# 4              5           7               1          42       1.0
# ...          ...         ...             ...         ...       ...
# 4659        3198           7               5         268       1.0
# 4660        3490           9               3          48       1.0
# 4661        4579          13               6         306       4.0
# 4662        3882          11               1         100       4.0
# 4663        4183           3               1         102       1.0
#
#      data_checkin data_checkout  qtd_diarias  num_hospedes  avaliacao_hospede  \
# 0      2024-04-28    2024-04-30            2             1                4.0
# ...

# %%
df_reserva.loc[727, 'qtd_diarias'] = 7
df_reserva.loc[954, 'qtd_diarias'] = 4
df_reserva.loc[1133, 'qtd_diarias'] = 3
df_reserva.loc[1151, 'qtd_diarias'] = 2
df_reserva.loc[1447, 'qtd_diarias'] = 6
df_reserva.loc[1580, 'qtd_diarias'] = 4
df_reserva.loc[2311, 'qtd_diarias'] = 4
df_reserva.loc[2383, 'qtd_diarias'] = 2
df_reserva.loc[2383, 'qtd_diarias'] = 2
df_reserva.loc[2383, 'qtd_diarias'] = 2
df_reserva.loc[2383, 'qtd_diarias'] = 2
df_reserva.loc[2383, 'qtd_diarias'] = 2
df_reserva.loc[2567, 'qtd_diarias'] = 1
df_reserva.loc[3135, 'qtd_diarias'] = 1
df_reserva.loc[3193, 'qtd_diarias'] = 1
df_reserva.loc[4468, 'qtd_diarias'] = 1

# %%
df_reserva.loc[df_reserva['id_reserva'] == 4030, 'qtd_diarias'] = 1

# %%
df_reserva.loc[(df_reserva['id_reserva'] == 4030)]
# Out:
#       id_reserva  id_unidade  id_tipo_quarto  id_cliente  id_canal  \
# 4545        4030          12               2          41       2.0
#
#      data_checkin data_checkout  qtd_diarias  num_hospedes  avaliacao_hospede  \
# 4545   2026-08-31    2026-09-01            1             2                9.0
#
#      status_reserva    forma_pagamento
# 4545     Confirmada  Cartão de Crédito

# %%
df_reserva.iloc[727, :]
df_reserva.iloc[954, :]
df_reserva.iloc[1133, :]
df_reserva.iloc[1151, :]
df_reserva.iloc[1447, :]
df_reserva.iloc[1580, :]
df_reserva.iloc[2311, :]
df_reserva.iloc[2383, :]
# Out:
# id_reserva                 2384
# id_unidade                    5
# id_tipo_quarto                2
# id_cliente                   64
# id_canal                    2.0
# data_checkin         2024-01-10
# data_checkout        2024-03-10
# qtd_diarias                   2
# num_hospedes                  2
# avaliacao_hospede           4.0
# status_reserva        Concluída
# forma_pagamento        Dinheiro
# Name: 2383, dtype: object

# %%
df_reserva.loc[df_reserva['id_reserva'] == 37, 'avaliacao_hospede'] = 1
df_reserva.loc[df_reserva['id_reserva'] == 902, 'avaliacao_hospede'] = 1
df_reserva.loc[df_reserva['id_reserva'] == 2073, 'avaliacao_hospede'] = 1
df_reserva.loc[df_reserva['id_reserva'] == 933, 'avaliacao_hospede'] = 3
df_reserva.loc[df_reserva['id_reserva'] == 1718, 'avaliacao_hospede'] = 3
df_reserva.loc[df_reserva['id_reserva'] == 2167, 'avaliacao_hospede'] = 3
df_reserva.loc[df_reserva['id_reserva'] == 3541, 'avaliacao_hospede'] = 1
df_reserva.loc[df_reserva['id_reserva'] == 2874, 'avaliacao_hospede'] = 1
df_reserva.loc[df_reserva['id_reserva'] == 4127, 'avaliacao_hospede'] = 1
df_reserva.loc[df_reserva['id_reserva'] == 4088, 'avaliacao_hospede'] = 3
df_reserva.loc[df_reserva['id_reserva'] == 568, 'num_hospedes'] = 1
df_reserva.loc[df_reserva['id_reserva'] == 675, 'num_hospedes'] = 2
df_reserva.loc[df_reserva['id_reserva'] == 903, 'num_hospedes'] = 1
df_reserva.loc[df_reserva['id_reserva'] == 1201, 'num_hospedes'] = 2
df_reserva.loc[df_reserva['id_reserva'] == 1883, 'num_hospedes'] = 2
df_reserva.loc[df_reserva['id_reserva'] == 2427, 'num_hospedes'] = 2
df_reserva.loc[df_reserva['id_reserva'] == 4463, 'num_hospedes'] = 1
df_reserva.loc[df_reserva['id_reserva'] == 4506, 'num_hospedes'] = 2
df_reserva.loc[df_reserva['id_reserva'] == 4040, 'num_hospedes'] = 2
df_reserva.loc[df_reserva['id_reserva'] == 2687, 'num_hospedes'] = 2

# %%
import numpy as np


df_reserva.loc[df_reserva['id_reserva'] == 194, 'avaliacao_hospede'] = np.nan
df_reserva.loc[df_reserva['id_reserva'] == 1538, 'avaliacao_hospede'] = np.nan
df_reserva.loc[df_reserva['id_reserva'] == 1866, 'avaliacao_hospede'] = np.nan
df_reserva.loc[df_reserva['id_reserva'] == 2210, 'avaliacao_hospede'] = np.nan
df_reserva.loc[(df_reserva['id_reserva'] == 1866)]
# Out:
#       id_reserva  id_unidade  id_tipo_quarto  id_cliente  id_canal  \
# 1865        1866           7               3         263       4.0
#
#      data_checkin data_checkout  qtd_diarias  num_hospedes  avaliacao_hospede  \
# 1865   2024-07-04    2024-09-04            2             2                NaN
#
#      status_reserva forma_pagamento
# 1865      Concluída        Dinheiro

# %%
df_reserva['data_checkout'] = pd.to_datetime(
    df_reserva['data_checkout'],
    format='mixed',
    dayfirst=True,
    errors='coerce'
)
df_reserva['data_checkin'] = pd.to_datetime(
    df_reserva['data_checkin'],
    format='mixed',
    dayfirst=True,
    errors='coerce'
)

df_reserva['status_reserva'] = df_reserva['status_reserva'].str.strip().str.title()
df_reserva['forma_pagamento'] = df_reserva['forma_pagamento'].str.strip().str.title()
df_reserva.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4664 entries, 0 to 4663
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_reserva         4664 non-null   int64
#  1   id_unidade         4664 non-null   int64
#  2   id_tipo_quarto     4664 non-null   int64
#  3   id_cliente         4664 non-null   int64
#  4   id_canal           4455 non-null   float64
#  5   data_checkin       4664 non-null   datetime64[us]
#  6   data_checkout      4664 non-null   datetime64[us]
#  7   qtd_diarias        4664 non-null   int64
#  8   num_hospedes       4664 non-null   int64
#  9   avaliacao_hospede  4014 non-null   float64
#  10  status_reserva     4664 non-null   str
#  11  forma_pagamento    4664 non-null   str
# dtypes: datetime64[us](2), float64(2), int64(6), str(2)
# memory usage: 437.4 KB

# %%
print (df_reserva['status_reserva'].sort_values().unique())
print(df_reserva['forma_pagamento'].sort_values().unique())
# Out:
# <StringArray>
# [   'Cancel.',  'Cancelada',  'Concluida',  'Concluída',      'Conf.',
#  'Confirmada',    'No-Show']
# Length: 7, dtype: str
# <StringArray>
# [       'C. Crédito',    'Cartao Credito',     'Cartao Debito',
#  'Cartão De Crédito',  'Cartão De Débito',              'Cash',
#                 'Cc',                'Cd',              'Cred',
#           'Dinheiro',               'Déb',               'Pix',
#                'Ted',     'Transferencia',     'Transferência']
# Length: 15, dtype: str

# %%
rese = {
    'Cancel.':                'Cancelada',
    'Concluida':                  'Concluída',
    'Conf.':                   'Confirmada'
    }
df_reserva['status_reserva'] = df_reserva['status_reserva'].map(rese).fillna(df_reserva['status_reserva'])

print('Após mapeamento:')
print(sorted(df_reserva['status_reserva'].unique()))

df_reserva
# Out:
# Após mapeamento:
# ['Cancelada', 'Concluída', 'Confirmada', 'No-Show']
#       id_reserva  id_unidade  id_tipo_quarto  id_cliente  id_canal  \
# 0              1           5               1           3       2.0
# 1              2           5               1         261       4.0
# 2              3          10               4          49       4.0
# 3              4           6               2          23       2.0
# 4              5           7               1          42       1.0
# ...          ...         ...             ...         ...       ...
# 4659        3198           7               5         268       1.0
# 4660        3490           9               3          48       1.0
# 4661        4579          13               6         306       4.0
# 4662        3882          11               1         100       4.0
# 4663        4183           3               1         102       1.0
#
#      data_checkin data_checkout  qtd_diarias  num_hospedes  avaliacao_hospede  \
# ...

# %%
forma = {
    'C. Crédito':                'Cartão De Crédito',
    'Cartao Credito':            'Cartão De Crédito',
    'Cred':                      'Cartão De Crédito',
    'Cc':                        'Cartão De Crédito',
    'Cartao Debito':             'Cartão De Débito',
    'Cd':                        'Cartão De Débito',
    'Déb':                       'Cartão De Débito',
    'Cash':                      'Dinheiro',
    'Ted':                       'Transferência',
    'Transferencia':             'Transferência'

    }
df_reserva['forma_pagamento'] = df_reserva['forma_pagamento'].map(forma).fillna(df_reserva['forma_pagamento'])

print('Após mapeamento:')
print(sorted(df_reserva['forma_pagamento'].unique()))

df_reserva
# Out:
# Após mapeamento:
# ['Cartão De Crédito', 'Cartão De Débito', 'Dinheiro', 'Pix', 'Transferência']
#       id_reserva  id_unidade  id_tipo_quarto  id_cliente  id_canal  \
# 0              1           5               1           3       2.0
# 1              2           5               1         261       4.0
# 2              3          10               4          49       4.0
# 3              4           6               2          23       2.0
# 4              5           7               1          42       1.0
# ...          ...         ...             ...         ...       ...
# 4659        3198           7               5         268       1.0
# 4660        3490           9               3          48       1.0
# 4661        4579          13               6         306       4.0
# 4662        3882          11               1         100       4.0
# 4663        4183           3               1         102       1.0
#
# ...

# %%
df_reserva.duplicated().sum()
df_reserva[df_reserva.duplicated(keep=False)]
df_reserva.duplicated(subset=['id_reserva',	'id_unidade',	'id_tipo_quarto',	'id_cliente',	'id_canal',	'data_checkin',	'data_checkout',	'qtd_diarias', 'num_hospedes',	'avaliacao_hospede',	'status_reserva',	'forma_pagamento' ]).sum()
# Out:
# np.int64(15)

# %%
df_reserva = df_reserva.drop_duplicates()
df_reserva.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_reserva.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_reserva
# Out:
#       id_reserva  id_unidade  id_tipo_quarto  id_cliente  id_canal  \
# 0              1           5               1           3       2.0
# 1              2           5               1         261       4.0
# 2              3          10               4          49       4.0
# 3              4           6               2          23       2.0
# 4              5           7               1          42       1.0
# ...          ...         ...             ...         ...       ...
# 4659        3198           7               5         268       1.0
# 4660        3490           9               3          48       1.0
# 4661        4579          13               6         306       4.0
# 4662        3882          11               1         100       4.0
# 4663        4183           3               1         102       1.0
#
#      data_checkin data_checkout  qtd_diarias  num_hospedes  avaliacao_hospede  \
# 0      2024-04-28    2024-04-30            2             1                4.0
# ...

# %%
df_reserva.to_csv('reservas.concat.csv', sep=';', index=False)

# %% [markdown]
# concatenado reserva antigo e novo
# prenchido e consertado valores
# numeros de avaliação transformados em nulo
# padronização de escrita

# %%
df_funci = pd.read_csv ('funcionarios_novos.csv', sep=';')
df_funci.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_funcionario  10 non-null     int64
#  1   id_unidade      10 non-null     int64
#  2   nome            10 non-null     str
#  3   cargo           10 non-null     str
#  4   departamento    10 non-null     str
#  5   salario         9 non-null      str
#  6   data_admissao   10 non-null     str
# dtypes: int64(2), str(5)
# memory usage: 692.0 bytes

# %%
df_funci['cargo'] = df_funci['cargo'].str.strip().str.title()
df_funci['cargo'].value_counts()
# Out:
# cargo
# Sommelier              2
# Analista Financeiro    2
# Segurança              2
# Concierge              1
# Auxiliar De Limpeza    1
# Chef De Cozinha        1
# Manobrista             1
# Name: count, dtype: int64

# %%
df_funci['departamento'] = df_funci ['departamento'].str.strip().str.title()
df_funci['departamento'].value_counts()
# Out:
# departamento
# Governança    3
# A&B           3
# Financeiro    2
# Operações     2
# Name: count, dtype: int64

# %%
df_funci['departamento'].value_counts()
dep = {'A&B':                   'Alimentos e Bebidas'}
df_funci['departamento'] = df_funci['departamento'].map(dep).fillna(df_funci['departamento'])

print('Após mapeamento:')
print(sorted(df_funci['departamento'].unique()))
# Out:
# Após mapeamento:
# ['Alimentos e Bebidas', 'Financeiro', 'Governança', 'Operações']

# %%
df_funci['salario'] = (
df_funci['salario']
.str.replace('.', '', regex=False)
.str.replace('"', '', regex=False)
.str.replace(',', '.', regex=False)
.astype(float)
)

# %%
df_funci['salario']
# Out:
# 0    3987.71
# 1    2432.01
# 2    3651.51
# 3    8545.89
# 4    9187.66
# 5    4710.88
# 6    8932.76
# 7        NaN
# 8    2782.48
# 9    8289.01
# Name: salario, dtype: float64

# %%
df_funci['data_admissao'] = pd.to_datetime(
    df_funci['data_admissao'],
    format='mixed',
    dayfirst=True,
    errors='coerce'
)
df_funci.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_funcionario  10 non-null     int64
#  1   id_unidade      10 non-null     int64
#  2   nome            10 non-null     str
#  3   cargo           10 non-null     str
#  4   departamento    10 non-null     str
#  5   salario         9 non-null      float64
#  6   data_admissao   10 non-null     datetime64[us]
# dtypes: datetime64[us](1), float64(1), int64(2), str(3)
# memory usage: 692.0 bytes

# %%
df_funci.to_csv('funcionarios_novos.csv', sep=';', index=False)
df_funci
# Out:
#    id_funcionario  id_unidade             nome                cargo  \
# 0             135          13   Marcos Andrade            Concierge
# 1             136          13   Fernanda Lopes            Sommelier
# 2             137          13    Ricardo Nunes            Sommelier
# 3             138          13    Patrícia Melo  Analista Financeiro
# 4             139          13    Bruno Cardoso  Auxiliar De Limpeza
# 5             140          13  Camila Ferreira            Segurança
# 6             141          13      Diego Ramos  Analista Financeiro
# 7             142          13    Juliana Prado      Chef De Cozinha
# 8             143          13     Leonardo Vaz           Manobrista
# 9             144          13    Renata Castro            Segurança
#
#           departamento  salario data_admissao
# 0           Governança  3987.71    2024-05-22
# 1           Governança  2432.01    2024-05-04
# 2  Alimentos e Bebidas  3651.51    2025-12-07
# ...

# %% [markdown]
# padronizado nomes
# convertido salario para float
# salvo funcionario novos

# %%
df_funcionarios = pd.concat([df_fun, df_funci], ignore_index=True)
df_funcionarios
 sep=';', index=False)
# Out:
#      id_funcionario  id_unidade             nome                cargo  \
# 0                 1           1    Gabriela Lima  Auxiliar De Limpeza
# 1                 2           1     Abel Correia            Segurança
# 2                 3           1    Sara Teixeira  Analista Financeiro
# 3                 4           1   Julia Monteiro  Auxiliar De Limpeza
# 4                 5           1    Daniela Ramos  Auxiliar De Limpeza
# ..              ...         ...              ...                  ...
# 139             140          13  Camila Ferreira            Segurança
# 140             141          13      Diego Ramos  Analista Financeiro
# 141             142          13    Juliana Prado      Chef De Cozinha
# 142             143          13     Leonardo Vaz           Manobrista
# 143             144          13    Renata Castro            Segurança
#
#             departamento  salario data_admissao
# 0             Governança  2139.00    2020-10-05
# ...

# %%
df_funcionarios.loc[df_funcionarios['id_funcionario'] == 142, 'salario'] = 7850
df_funcionarios.loc[(df_funcionarios['id_funcionario'] == 142)]
# Out:
#      id_funcionario  id_unidade           nome            cargo departamento  \
# 141             142          13  Juliana Prado  Chef De Cozinha    Operações
#
#      salario data_admissao
# 141   7850.0    2024-12-03

# %%
display(df_funcionarios.describe(include='object'))
df_funcionarios.info()
# Out:
# C:\Users\eduar\AppData\Local\Temp\ipykernel_11312\2671057528.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   display(df_funcionarios.describe(include='object'))
#                 nome       cargo departamento
# count            144         144          144
# unique            55          12            8
# top     Ursula Pinto  Manutenção   Governança
# freq               8          24           41
# <class 'pandas.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ...

# %%
df_funcionarios.duplicated().sum()
df_funcionarios[df_funcionarios.duplicated(keep=False)]
df_funcionarios.duplicated(subset=['id_funcionario',	'id_unidade',	'nome',	'cargo',	'departamento',	'salario',	'data_admissao']).sum()
# Out:
# np.int64(0)

# %%
df_funcionarios.to_csv('funcionarios.concat.csv', sep=';', ignore_index=True)
df_funcionarios
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 df_funcionarios.to_csv('funcionarios.concat.csv', sep=';', ignore_index=True)
#       2 df_funcionarios
#
# TypeError: NDFrame.to_csv() got an unexpected keyword argument 'ignore_index'

# %% [markdown]
# concatenado funcionários
# salários consertados

# %%
df_clien = pd.read_csv('clientes_novos.csv', sep=';')
df_clien
# Out:
#     id_cliente                   nome   cidade_origem estado_origem  \
# 0          301  Alexandre Bittencourt          Lisboa            EX
# 1          302         Beatriz Falcão  Belo Horizonte            MG
# 2          303             Caio Serpa  Belo Horizonte            MG
# 3          304     Débora Vasconcelos           Miami            EX
# 4          305         Eduardo Mourão    Buenos Aires            EX
# 5          306        Fabiana Restier    Porto Alegre            rs
# 6          307        Gustavo Peixoto       Nova York            EX
# 7          308        Helena Quintela        Brasília            DF
# 8          309           Igor Salgado        Brasília            DF
# 9          310           Joana Villar    Porto Alegre            RS
# 10         311    Kleber Andrade Neto        Curitiba            PR
# 11         312     Larissa Monteverde       São Paulo            SP
# 12         313       Marcelo Trindade  Rio de Janeiro            RJ
# ...

# %%
df_clien['cidade_origem'].sort_values().unique()
df_clien['estado_origem'].sort_values()
print(sorted(df_clien['cidade_origem'].unique()))
print(sorted(df_clien['estado_origem'].unique()))
# Out:
# ['Belo Horizonte', 'Brasília', 'Buenos Aires', 'Curitiba', 'Lisboa', 'Miami', 'Nova York', 'Porto Alegre', 'Rio de Janeiro', 'São Paulo']
# ['DF', 'EX', 'MG', 'PR', 'RJ', 'RS', 'SP', 'rs']

# %%
df_clien[df_clien.isnull().any(axis=1)]
# Out:
#     id_cliente                nome cidade_origem estado_origem faixa_etaria  \
# 3          304  Débora Vasconcelos         Miami            EX          NaN
# 15         316  Priscila Guimarães        Lisboa            EX          NaN
#
#    tipo_cliente
# 3            PF
# 15           PF

# %%
mapa_cidades = {
    'rs': 'RS',
}

df_clien['estado_origem'] = df_clien['estado_origem'].map(mapa_cidades).fillna(df_clien['estado_origem'])

print('Após mapeamento:')
print(sorted(df_clien['estado_origem'].unique()))
# Out:
# Após mapeamento:
# ['DF', 'EX', 'MG', 'PR', 'RJ', 'RS', 'SP']

# %%
print(sorted(df_clien['tipo_cliente'].unique()))
# Out:
# ['Corporativo', 'PF', 'PJ', 'Pessoa Física', 'Pessoa Jurídica']

# %%
tipo = {
    'PF':   'Pessoa Física',
    'Pessoa Jurídica':  'Corporativo',
    'PJ':   'Corporativo',
    'CorporativoPJCorporativo': 'Corporativo'
}

df_clien['tipo_cliente'] = df_clien['tipo_cliente'].map(tipo).fillna(df_clien['tipo_cliente'])

print('Após mapeamento:')
print(sorted(df_clien['tipo_cliente'].unique()))
# Out:
# Após mapeamento:
# ['Corporativo', 'Pessoa Física']

# %%
df_clien.to_csv('clientes_novos.csv',sep=';', index=False )

# %% [markdown]
# padronizado tipo de cliente
# padronizado estado

# %%
df_cliente = pd.concat([df_cli, df_clien], ignore_index=True)
df_cliente
# Out:
#      id_cliente                nome   cidade_origem estado_origem  \
# 0             1         Otavio Reis       São Paulo            SP
# 1             2       Larissa Sousa        Curitiba            PR
# 2             3      Tatiana Coelho  Rio de Janeiro            RJ
# 3             4       Wilson Duarte        Brasília            DF
# 4             5       Gabriela Lima  Rio de Janeiro            RJ
# ..          ...                 ...             ...           ...
# 316         316  Priscila Guimarães          Lisboa            EX
# 317         317     Rodrigo Vasques  Rio de Janeiro            RJ
# 318         318      Sabrina Leitão        Brasília            DF
# 319         319      Thiago Bicalho  Belo Horizonte            MG
# 320         320      Vivian Lacerda    Buenos Aires            EX
#
#     faixa_etaria   tipo_cliente
# 0          18-25    Corporativo
# 1          18-25  Pessoa Física
# 2            65+    Corporativo
# 3          26-35    Corporativo
# ...

# %%
df_cliente.to_csv('clientes.concat.csv', sep=';', index=False)
df_cliente
# Out:
#      id_cliente                nome   cidade_origem estado_origem  \
# 0             1         Otavio Reis       São Paulo            SP
# 1             2       Larissa Sousa        Curitiba            PR
# 2             3      Tatiana Coelho  Rio de Janeiro            RJ
# 3             4       Wilson Duarte        Brasília            DF
# 4             5       Gabriela Lima  Rio de Janeiro            RJ
# ..          ...                 ...             ...           ...
# 316         316  Priscila Guimarães          Lisboa            EX
# 317         317     Rodrigo Vasques  Rio de Janeiro            RJ
# 318         318      Sabrina Leitão        Brasília            DF
# 319         319      Thiago Bicalho  Belo Horizonte            MG
# 320         320      Vivian Lacerda    Buenos Aires            EX
#
#     faixa_etaria   tipo_cliente
# 0          18-25    Corporativo
# 1          18-25  Pessoa Física
# 2            65+    Corporativo
# 3          26-35    Corporativo
# ...

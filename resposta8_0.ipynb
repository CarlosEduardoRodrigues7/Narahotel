# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv ('canais_venda.csv', sep=';')
pd.read_csv ('clientes.concat.csv', sep=';')
pd.read_csv ('funcionarios.concat.csv', sep=';')
pd.read_csv ('reservas.concat.corrigido.csv', sep=';')
pd.read_csv ('tipos_quarto.concat.csv', sep=';')
pd.read_csv ('unidades.concat.csv', sep=';')
# Out:
#     id_unidade                   nome_unidade          cidade  \
# 0            1             NaraHoteis Ipanema  Rio de Janeiro
# 1            2     NaraHoteis Barra da Tijuca  Rio de Janeiro
# 2            3              NaraHoteis Centro  Rio de Janeiro
# 3            4        NaraHoteis Santa Teresa  Rio de Janeiro
# 4            5  NaraHoteis Nova Iguaçu Centro     Nova Iguaçu
# 5            6    NaraHoteis Nova Iguaçu Park     Nova Iguaçu
# 6            7          NaraHoteis Petrópolis      Petrópolis
# 7            8         NaraHoteis Teresópolis     Teresópolis
# 8            9            NaraHoteis Friburgo   Nova Friburgo
# 9           10              NaraHoteis Paraty          Paraty
# 10          11      NaraHoteis Angra dos Reis  Angra dos Reis
# 11          12         NaraHoteis Mangaratiba     Mangaratiba
# 12          13  NaraHoteis Copacabana Premium  Rio de Janeiro
#
#                 regiao  categoria_hotel(estrelas)  num_quartos_total
# ...

# %% [markdown]
# PERGUNTA
#
# Quero entender se a nossa nova unidade, Copacabana Premium, está performando à altura do investimento feito e do posicionamento 5 estrelas que adotamos para ela. Comparem o desempenho dela com o restante da rede e me tragam o que os dados mostram.
#
# RESPOSTA 8
#
# O cliente aceitou o posicionamento 5 estrelas. A Mediana de faturamento por reserva em Copacabana é de R$ 1.900,00 — a segunda mais alta de toda a rede. O hóspede entra ciente de que é um produto caro e paga por isso sem depreciar a diária.
#
# Gargalo de Volume: Sendo a unidade recém-inaugurada, ela amarga o último lugar absoluto em tração, com apenas 130 reservas e Faturamento Total de R$ 298.500,00. Esse volume anêmico derruba a eficiência (RevPAR) para meros R$ 248,75, deixando um ativo de luxo operando no mesmo nível de rentabilidade diária das problemáticas unidades do Centro. Em resumo: o hotel é caro, mas vive de quartos vazios.
#
# Alerta na Avaliação: A nota média de Copacabana está em 7,08. Para um hotel que carrega o selo "Premium" e cobra o tíquete mais alto da rede, essa avaliação é perigosa. Unidades padrão de lazer, como Ipanema e Santa Teresa, beiram a nota 8,0. Isso indica que o cliente de Copacabana entra com expectativa de luxo, paga preço de luxo, mas não sente que a entrega da operação justifica o custo.
